# %% [markdown]
# # Matplotlib

# %% [markdown]
# ### Simple plot

# %%
import numpy as np
x = np.linspace(-np.pi,np.pi,256)

# %%
c,s = np.cos(x),np.sin(x)

# %% [markdown]
# ### using defualts

# %%
from matplotlib import pyplot as plt
plt.plot(x,c)
plt.plot(x,s)
# plt.show()

# %% [markdown]
# ### changing colors and line widths

# %%
plt.figure(figsize=(10,6))
plt.plot(x,c,color='blue',linewidth=2.5)
plt.plot(x,s,color='red',linewidth=2.5)

# %% [markdown]
# ### setting limits

# %%
plt.figure()
plt.plot(x,c,color='blue',linewidth=2.5)
plt.plot(x,s,color='red',linewidth=2.5)

plt.xlim(-2,+2)
plt.ylim(c.min()*1.1,c.max()*1.1)
# Out:
# (-1.1, 1.0999165211263138)

# %% [markdown]
# ### seting ticks

# %%
plt.figure()
plt.plot(x,c,color='blue',linewidth=2.5)
plt.plot(x,s,color='red',linewidth=2.5)

plt.xticks([-np.pi,0,np.pi])
plt.yticks([-1,0,1])
# Out:
# ([<matplotlib.axis.YTick at 0x2321e4646a0>,
# ...
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %% [markdown]
# ### setting tick labels

# %%
plt.figure()
plt.plot(x,c,color='blue',linewidth=2.5)
plt.plot(x,s,color='red',linewidth=2.5)

plt.xticks([-np.pi,0,np.pi],[r'$-\pi$',0,r'$+\pi$'])
plt.yticks([-1,0,1])
# Out:
# ([<matplotlib.axis.YTick at 0x2321e4b6580>,
# ...
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %% [markdown]
# ### Adding legend

# %%
plt.figure()
plt.plot(x,c,color='black',linewidth=2.5,label = 'Cosine', dashes=(2,2))
plt.plot(x,s,color='black',linewidth=2.5,label = 'Sine')

plt.xticks([-np.pi,0,np.pi],[r'$-\pi$',0,r'$+\pi$'])
plt.yticks([-1,0,1])
plt.legend()
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# ### Annotating some point

# %%
plt.figure()
plt.plot(x,c,color='blue',linewidth=2.5,label = 'Cosine')
plt.plot(x,s,color='green',linewidth=2.5,label = 'Sine')

plt.xticks([-np.pi,0,np.pi],[r'$-\pi$',0,r'$+\pi$'])
plt.yticks([-1,0,1])
plt.legend()
plt.xlabel('x')
plt.ylabel('f(x)')

##############################
t = 2*np.pi/3

plt.plot([t,t],[0,np.cos(t)],color='red', linewidth=1.5,linestyle='--')
plt.scatter([t,],[np.cos(t),],50,color='red')
plt.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',
            xy=(t,np.cos(t)), xycoords='data',
            xytext = (-90,-50),textcoords='offset points',
            fontsize=16, arrowprops=dict(arrowstyle='->'))
# Out:
# Text(-90, -50, '$\\cos(\\frac{2\\pi}{3})=-\\frac{1}{2}$')

# %% [markdown]
# ### Multi plots

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(x,x)
plt.subplot(2,3,4)
plt.plot(x,c)
plt.subplot(2,3,5)
plt.plot(x,s)

fig.subplots_adjust(bottom=0.025,left=0.035,top=0.975,right=0.975,
                   wspace=0.4,hspace=0.4)
fig.savefig('test.png')

# %%
import matplotlib.pyplot as plt

# Horizontal bar plot with gaps
fig, ax = plt.subplots()
ax.broken_barh([(110, 30), (150, 10)], (10, 9), facecolors='tab:blue')
ax.broken_barh([(10, 50), (100, 20), (130, 10)], (20, 9),
               facecolors=('tab:orange', 'tab:green', 'tab:red'))
ax.set_ylim(5, 35)
ax.set_xlim(0, 200)
ax.set_xlabel('seconds since start')
ax.set_yticks([15, 25], labels=['Bill', 'Jim'])     # Modify y-axis tick labels
ax.grid(True)                                       # Make grid lines visible
ax.annotate('race interrupted', (61, 25),
            xytext=(0.8, 0.9), textcoords='axes fraction',
            arrowprops=dict(facecolor='black', shrink=0.05),
            fontsize=16,
            horizontalalignment='right', verticalalignment='top')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


y = np.arange(0.0, 2, 0.01)
x1 = np.sin(2 * np.pi * y)
x2 = 1.2 * np.sin(4 * np.pi * y)

fig, [ax1, ax2, ax3] = plt.subplots(1, 3, sharey=True, figsize=(6, 6))

ax1.fill_betweenx(y, 0, x1)
ax1.set_title('between (x1, 0)')

ax2.fill_betweenx(y, x1, 1)
ax2.set_title('between (x1, 1)')
ax2.set_xlabel('x')

ax3.fill_betweenx(y, x1, x2)
ax3.set_title('between (x1, x2)')
# Out:
# Text(0.5, 1.0, 'between (x1, x2)')
